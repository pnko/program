# %%
#02. Random 함수를 이용한 단순회귀 실습
import numpy as np
num_points = 1000
vectors_set = []

for i in range(num_points):
    x1 = np.random.normal(0.0, 0.55)
    y1 = x1 * 0.1 +0.3 + np.random.normal(0.0, 0.03)
    vectors_set.append([x1, y1])

x_data = [v[0] for v in vectors_set]
y_data = [v[1] for v in vectors_set]

import matplotlib.pyplot as plt

plt.plot(x_data, y_data, 'ro')
plt.show()

# %%
#03. 선형회귀분석
import  tensorflow as tf

W = tf.Variabjle(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.zeros([1]))
y = W * x_data +b

loss = tf.reduce_mean(tf.square(y - y_data))

optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)

#실행부
init = tf.global_variables_initializer()

sess = tf.Session()
sess.run(init)

for step in range(8) :
    sess.run(train)
    print(step, sess.run(W), sess.run(b),  sess.run(loss))
    plt.plot(x_data, y_data, 'ro')
    plt.plot(x_data, sess.run(W) * x_data + sess.run(b))
    plt.xlabel('x')
    plt.ylabel('y')
    plt.show()
# Out:
# 0 [ 0.71324396] [ 0.32151699] 0.113843
# 1 [ 0.52983689] [ 0.31485093] 0.0565235
# 2 [ 0.40112153] [ 0.31037048] 0.0282951
# 3 [ 0.31079364] [ 0.30722609] 0.0143933
# 4 [ 0.24740477] [ 0.30501947] 0.00754712
# 5 [ 0.20292073] [ 0.30347097] 0.00417554
# 6 [ 0.17170343] [ 0.30238426] 0.00251512
# 7 [ 0.14979623] [ 0.30162165] 0.00169741

# %%
##########################################
# MINST 
########################################

# %%
import input_data
import numpy as np
import matplotlib.pyplot as plt
mnist_images = input_data.read_data_sets\
               ("MNIST_data/",\
                one_hot=False)
    
train.next_batch(10)
pixels,real_values = mnist_images.train.next_batch(10)
print("list of values loaded ",real_values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-8a10835f9b05> in <module>()
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 mnist_images = input_data.read_data_sets               ("MNIST_data/",                one_hot=False)
#       5
#       6 train.next_batch(10)
#
# C:\kimhk\workspace\program\Python\IPNB\input_data.py in read_data_sets(train_dir, fake_data, one_hot, dtype)
#     191   VALIDATION_SIZE = 5000
#     192
# --> 193   local_file = maybe_download(TRAIN_IMAGES, train_dir)
#     194   train_images = extract_images(local_file)
#     195
#
# C:\kimhk\workspace\program\Python\IPNB\input_data.py in maybe_download(filename, work_directory)
#      38     filepath, _ = urllib.request.urlretrieve(SOURCE_URL + filename, filepath)
#      39     with tf.gfile.GFile(filepath) as f:
# ---> 40       size = f.Size()
#      41     print('Successfully downloaded', filename, size, 'bytes.')
#      42   return filepath
#
# AttributeError: 'GFile' object has no attribute 'Size'
